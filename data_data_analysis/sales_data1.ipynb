# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 400)

# %%
df = pd.read_csv("C:/Users/ncc/Desktop/Data_set/sales_data.xls")
df
# Out:
#                                  customer_id  \
# 0       cda7bec0-7cbf-4145-baf9-e049bab94504
# 1       cda7bec0-7cbf-4145-baf9-e049bab94504
# 2       cda7bec0-7cbf-4145-baf9-e049bab94504
# 3       cda7bec0-7cbf-4145-baf9-e049bab94504
# 4       cda7bec0-7cbf-4145-baf9-e049bab94504
# ...                                      ...
# 578315  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578316  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578317  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578318  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578319  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                    device_id  item_id  line_item_id  \
# 0       33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# 1       33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# 2       33b485de-7338-4997-b1d0-b988ba17b245        9          3203
# 3       33b485de-7338-4997-b1d0-b988ba17b245       12          3204
# 4       33b485de-7338-4997-b1d0-b988ba17b245        6          3205
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 578320 entries, 0 to 578319
# Data columns (total 12 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   customer_id      578320 non-null  object
#  1   device_id        578320 non-null  object
#  2   item_id          578320 non-null  int64
#  3   line_item_id     578320 non-null  int64
#  4   order_id         578320 non-null  object
#  5   event_id         578320 non-null  int64
#  6   event_timestamp  578320 non-null  object
#  7   quantity         578320 non-null  int64
#  8   currency         578320 non-null  object
#  9   checked_out_at   578320 non-null  object
#  10  status           578320 non-null  object
#  11  location         578320 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 52.9+ MB

# %%
df.isna().sum()
# Out:
# customer_id        0
# device_id          0
# item_id            0
# line_item_id       0
# order_id           0
# event_id           0
# event_timestamp    0
# quantity           0
# currency           0
# checked_out_at     0
# status             0
# location           0
# dtype: int64

# %%
df.columns
# Out:
# Index(['customer_id', 'device_id', 'item_id', 'line_item_id', 'order_id',
#        'event_id', 'event_timestamp', 'quantity', 'currency', 'checked_out_at',
#        'status', 'location'],
#       dtype='object')

# %%
print(len(df.columns))
# Out:
# 12

# %%
df.describe()
# Out:
#              item_id   line_item_id       event_id       quantity
# count  578320.000000  578320.000000  578320.000000  578320.000000
# mean        7.995741   19034.444880   88235.379821       3.009861
# std         4.322902    9153.541683   42541.874688       1.406914
# min         1.000000    3201.000000   14786.000000       1.000000
# 25%         4.000000   11108.000000   51318.000000       2.000000
# 50%         8.000000   19067.000000   88373.000000       3.000000
# 75%        12.000000   26960.000000  125003.000000       4.000000
# max        15.000000   34941.000000  161960.000000       5.000000

# %%
df.set_index("customer_id", inplace=True)
df.head(5)
# Out:
#                                                                  device_id  \
# customer_id
# cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
#
#                                       item_id  line_item_id  \
# customer_id
# cda7bec0-7cbf-4145-baf9-e049bab94504        4          3201
# cda7bec0-7cbf-4145-baf9-e049bab94504        5          3202
# cda7bec0-7cbf-4145-baf9-e049bab94504        9          3203
# cda7bec0-7cbf-4145-baf9-e049bab94504       12          3204
# cda7bec0-7cbf-4145-baf9-e049bab94504        6          3205
#
#                                                                   order_id  \
# customer_id
# ...

# %%
df.index
# Out:
# Index(['cda7bec0-7cbf-4145-baf9-e049bab94504',
#        'cda7bec0-7cbf-4145-baf9-e049bab94504',
#        'cda7bec0-7cbf-4145-baf9-e049bab94504',
#        'cda7bec0-7cbf-4145-baf9-e049bab94504',
#        'cda7bec0-7cbf-4145-baf9-e049bab94504',
#        'cda7bec0-7cbf-4145-baf9-e049bab94504',
#        'cda7bec0-7cbf-4145-baf9-e049bab94504',
#        'cda7bec0-7cbf-4145-baf9-e049bab94504',
#        'cda7bec0-7cbf-4145-baf9-e049bab94504',
#        'cda7bec0-7cbf-4145-baf9-e049bab94504',
#        ...
#        'ef15a7b3-326c-405f-9eef-3dbf43c85a9d',
#        'ef15a7b3-326c-405f-9eef-3dbf43c85a9d',
#        'ef15a7b3-326c-405f-9eef-3dbf43c85a9d',
#        'ef15a7b3-326c-405f-9eef-3dbf43c85a9d',
#        'ef15a7b3-326c-405f-9eef-3dbf43c85a9d',
#        'ef15a7b3-326c-405f-9eef-3dbf43c85a9d',
#        'ef15a7b3-326c-405f-9eef-3dbf43c85a9d',
#        'ef15a7b3-326c-405f-9eef-3dbf43c85a9d',
#        'ef15a7b3-326c-405f-9eef-3dbf43c85a9d',
#        'ef15a7b3-326c-405f-9eef-3dbf43c85a9d'],
# ...

# %%
df.index.unique().sort_values()
# Out:
# Index(['00096d0c-ced3-4913-afe9-5ce363f7126f',
#        '000c7914-248f-404c-bd49-49c7ae49364e',
#        '000d9458-f109-4fd1-9bc9-2514dde6c7d2',
#        '000e74fd-2f7f-447c-9fe5-a0e856e3e93f',
#        '001c37e2-f25c-45c1-8326-1ddf73c21dde',
#        '001d644f-d6dc-4540-9b31-74ac6c39665e',
#        '003adcf4-ec19-4fa8-b951-847fda032d0f',
#        '005adf1a-b0aa-46d7-9504-8a2f9d864d77',
#        '005c74be-edc4-41cc-b9fd-0a68dfd8bafe',
#        '006db9e0-aaa7-49bc-9659-2ac0a527cb03',
#        ...
#        'ff8477eb-f0c6-441f-a6cd-c9915386a7ef',
#        'ff8ef2dc-7484-4e88-b69e-cc10f0fcbbc5',
#        'ff92f8a9-cb19-4e08-8ec5-85fab6810984',
#        'ffa409df-6e87-4a7c-83f9-b9a75d9d60ea',
#        'ffa82f2f-4bfd-4210-a0ad-0aa97ff9949b',
#        'ffaf35ad-37fa-43f1-bed3-26bb53e612ae',
#        'ffc51ce7-426f-4e93-b98e-21be2202b40e',
#        'ffda8205-bed4-4067-b4f6-8ed1b4819c64',
#        'ffddb31d-9c3e-46b7-9ec2-efd272f6bd51',
#        'ffef23aa-84f4-45ba-96cc-2c4377220305'],
# ...

# %%
df.index.value_counts().sort_values(ascending=False).head(10)
# Out:
# customer_id
# eb7dcb88-073d-403e-bdd4-1e5725fe2338    372
# c391f179-9eb3-418d-9d7b-b261f2dc57a6    360
# be8ce4e3-c596-43c2-8b70-bdcecada2139    360
# 12e94262-2eaa-47d9-85c9-6f55e434f5c8    360
# ebcea232-0615-44be-8f9e-338100c6b31c    360
# ebcb2343-be1b-421e-83eb-6f79a321d999    360
# e4431b51-8db8-4b4a-a871-d12e3eaca47d    360
# a7d9058a-163e-4632-9bde-1f57130130cb    360
# 25ca6238-bc27-453a-b5e3-0a478f3f4e22    348
# e73af64f-4c71-417a-94cc-7e0f2379cd3e    348
# Name: count, dtype: int64

# %%
mask = (df.index == "eb7dcb88-073d-403e-bdd4-1e5725fe2338")

# %%
mask2 = (df.index == "eb7dcb88-073d-403e-bdd4-1e5725fe2338") & (df["status"] == "success")

# %%
df[mask].head(10)
# Out:
#                                                                  device_id  \
# customer_id
# eb7dcb88-073d-403e-bdd4-1e5725fe2338  5d53495a-55ac-49bf-b876-ad1ac4b8d2a4
# eb7dcb88-073d-403e-bdd4-1e5725fe2338  5d53495a-55ac-49bf-b876-ad1ac4b8d2a4
# eb7dcb88-073d-403e-bdd4-1e5725fe2338  5d53495a-55ac-49bf-b876-ad1ac4b8d2a4
# eb7dcb88-073d-403e-bdd4-1e5725fe2338  5d53495a-55ac-49bf-b876-ad1ac4b8d2a4
# eb7dcb88-073d-403e-bdd4-1e5725fe2338  5d53495a-55ac-49bf-b876-ad1ac4b8d2a4
# eb7dcb88-073d-403e-bdd4-1e5725fe2338  5d53495a-55ac-49bf-b876-ad1ac4b8d2a4
# eb7dcb88-073d-403e-bdd4-1e5725fe2338  5d53495a-55ac-49bf-b876-ad1ac4b8d2a4
# eb7dcb88-073d-403e-bdd4-1e5725fe2338  5d53495a-55ac-49bf-b876-ad1ac4b8d2a4
# eb7dcb88-073d-403e-bdd4-1e5725fe2338  5d53495a-55ac-49bf-b876-ad1ac4b8d2a4
# eb7dcb88-073d-403e-bdd4-1e5725fe2338  5d53495a-55ac-49bf-b876-ad1ac4b8d2a4
#
#                                       item_id  line_item_id  \
# customer_id
# ...

# %%
df.loc[mask2]
# Out:
# Empty DataFrame
# Columns: [device_id, item_id, line_item_id, order_id, event_id, event_timestamp, quantity, currency, checked_out_at, status, location]
# Index: []

# %%
mask3 = (df.index == "eb7dcb88-073d-403e-bdd4-1e5725fe2338") & (df["status"] == "failed")

# %%
df.loc[mask3]
# Out:
# Empty DataFrame
# Columns: [device_id, item_id, line_item_id, order_id, event_id, event_timestamp, quantity, currency, checked_out_at, status, location]
# Index: []

# %%
df.index.value_counts().sort_values(ascending=False).head(10).plot(kind = "bar")
plt.ylabel("Frequency")
plt.title("Top Ten Customer")
# Out:
# Text(0.5, 1.0, 'Top Ten Customer')

# %%
df["location"].unique()
# Out:
# array(['Saint Helena', 'Djibouti', 'Ecuador', 'Mali', 'Grenada',
#        'United States Minor Outlying Islands', 'Aruba', 'Germany',
#        'Saint Pierre and Miquelon', 'Sudan', 'Palestinian Territory',
#        'North Macedonia', 'Qatar', 'Israel', 'Netherlands Antilles',
#        'French Guiana', 'India', 'Switzerland', 'Canada', 'Philippines',
#        'Christmas Island', 'Micronesia', 'British Virgin Islands',
#        'Barbados', 'Guadeloupe', 'Chad', 'Bouvet Island (Bouvetoya)',
#        'Mauritania', 'Thailand', 'Tuvalu', 'Poland', 'Greenland',
#        'Saint Martin', 'Guatemala', 'Bermuda', 'Australia', 'Malawi',
#        'Mozambique', 'Costa Rica', 'Oman', 'Armenia', 'Tokelau',
#        'Myanmar', 'Angola', 'Sierra Leone', 'Denmark',
#        'Falkland Islands (Malvinas)', 'Taiwan', 'Norfolk Island', 'Egypt',
#        'Yemen', 'Cocos (Keeling) Islands', 'Northern Mariana Islands',
#        'Chile', 'Iraq', 'Antigua and Barbuda', 'Guam', 'Bahrain',
# ...

# %%
df["location"].nunique()
# Out:
# 243

# %%
df["location"].value_counts().sort_values(ascending=False).head(10)
# Out:
# location
# Korea            6997
# Argentina        4507
# Mauritius        4414
# Jersey           4130
# Panama           3936
# French Guiana    3851
# Guernsey         3804
# Guatemala        3731
# Albania          3721
# Philippines      3675
# Name: count, dtype: int64

# %%
df["location"].value_counts().sort_values(ascending=False).head(10).plot(kind = "bar")
plt.ylabel("Frequency")
plt.title("Top Ten Countries with the Highest Patronage")
# Out:
# Text(0.5, 1.0, 'Top Ten Countries with the Highest Patronage')

# %%
df["currency"].unique()
# Out:
# array(['NGN', 'USD', 'GBP'], dtype=object)

# %%
Freq_of_currency = df["currency"].value_counts()
Freq_of_currency
# Out:
# currency
# USD    198037
# GBP    191403
# NGN    188880
# Name: count, dtype: int64

# %%
Freq_of_currency.plot(kind = "bar")
plt.ylabel("Frequency")
plt.title("Frequency of the Currency")
# Out:
# Text(0.5, 1.0, 'Frequency of the Currency')

# %%
mask4 = (df["status"] =="failed")

# %%
df.loc[mask4]
# Out:
#                                                                  device_id  \
# customer_id
# e7f07fd1-05af-494a-ae5a-78c405b6f9c3  428688d6-31e6-4c73-a5d0-c8e849ccf6a3
# e7f07fd1-05af-494a-ae5a-78c405b6f9c3  428688d6-31e6-4c73-a5d0-c8e849ccf6a3
# e7f07fd1-05af-494a-ae5a-78c405b6f9c3  428688d6-31e6-4c73-a5d0-c8e849ccf6a3
# e7f07fd1-05af-494a-ae5a-78c405b6f9c3  428688d6-31e6-4c73-a5d0-c8e849ccf6a3
# f40fc2b7-0a0f-46e8-8fc5-4edfa5eb832b  76c265ff-c670-433a-887f-4b0d7a991349
# ...                                                                    ...
# ef15a7b3-326c-405f-9eef-3dbf43c85a9d  74bb4936-9890-421b-a62a-ee544191fa1e
# ef15a7b3-326c-405f-9eef-3dbf43c85a9d  74bb4936-9890-421b-a62a-ee544191fa1e
# ef15a7b3-326c-405f-9eef-3dbf43c85a9d  74bb4936-9890-421b-a62a-ee544191fa1e
# ef15a7b3-326c-405f-9eef-3dbf43c85a9d  74bb4936-9890-421b-a62a-ee544191fa1e
# ef15a7b3-326c-405f-9eef-3dbf43c85a9d  74bb4936-9890-421b-a62a-ee544191fa1e
#
# ...

# %%
print("There is about",len(df.loc[mask4]), "failed transaction")
# Out:
# There is about 196383 failed transaction

# %%
# LEts find out the numbers of failed transaction as compared to others...
transaction_status = df["status"].value_counts()
transaction_status
# Out:
# status
# failed       196383
# success      192594
# cancelled    189343
# Name: count, dtype: int64

# %%
transaction_status.plot(kind = "bar")
plt.ylabel("Frequency")
plt.title("Transaction Status")
# Out:
# Text(0.5, 1.0, 'Transaction Status')

# %%
# Does the currency have effect on the status of currency...?
currency_by_status = df.groupby("currency")["status"].value_counts()
currency_by_status
# Out:
# currency  status
# GBP       cancelled    64324
#           success      64266
#           failed       62813
# NGN       success      66146
#           failed       65387
#           cancelled    57347
# USD       failed       68183
#           cancelled    67672
#           success      62182
# Name: count, dtype: int64

# %%
#since korea has the higest patronage, lets explore it
df_korea = df.loc[(df["location"] == "Korea")]
df_korea.head(5)
# Out:
#                                                                  device_id  \
# customer_id
# 3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9  01cf516e-66e6-45f2-a6d6-b6f5f5232778
# 3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9  01cf516e-66e6-45f2-a6d6-b6f5f5232778
# 3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9  01cf516e-66e6-45f2-a6d6-b6f5f5232778
# 3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9  01cf516e-66e6-45f2-a6d6-b6f5f5232778
# 3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9  01cf516e-66e6-45f2-a6d6-b6f5f5232778
#
#                                       item_id  line_item_id  \
# customer_id
# 3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9       14          3914
# 3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9        8          3915
# 3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9       10          3916
# 3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9        4          3917
# 3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9        7          3918
#
#                                                                   order_id  \
# customer_id
# ...

# %%
df_korea.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6997 entries, 3b0ae8c1-68c6-40c8-a13a-e2bffb5ffdf9 to e9345bdc-3b15-4cab-9526-0d690021db61
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   device_id        6997 non-null   object
#  1   item_id          6997 non-null   int64
#  2   line_item_id     6997 non-null   int64
#  3   order_id         6997 non-null   object
#  4   event_id         6997 non-null   int64
#  5   event_timestamp  6997 non-null   object
#  6   quantity         6997 non-null   int64
#  7   currency         6997 non-null   object
#  8   checked_out_at   6997 non-null   object
#  9   status           6997 non-null   object
#  10  location         6997 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 914.0+ KB

# %%
df_korea.shape
# Out:
# (6997, 11)

# %%
failed_transc = df_korea[df_korea["status"] == "failed"]
successful_transc = df_korea[df_korea["status"] == "success"]
cancelled_transc = df_korea[df_korea["status"] == "cancelled"]

# %%
failed_transc
# Out:
#                                                                  device_id  \
# customer_id
# 34d3c5e1-7e40-40c9-84c3-7d50edfb7eaf  05ec37c1-5bb4-4033-908b-366e25c02f66
# 34d3c5e1-7e40-40c9-84c3-7d50edfb7eaf  05ec37c1-5bb4-4033-908b-366e25c02f66
# 34d3c5e1-7e40-40c9-84c3-7d50edfb7eaf  05ec37c1-5bb4-4033-908b-366e25c02f66
# 34d3c5e1-7e40-40c9-84c3-7d50edfb7eaf  05ec37c1-5bb4-4033-908b-366e25c02f66
# 34d3c5e1-7e40-40c9-84c3-7d50edfb7eaf  05ec37c1-5bb4-4033-908b-366e25c02f66
# ...                                                                    ...
# be397c29-0766-4bf0-a315-fa230d7e41d9  b2af6377-ea73-4520-8f55-8b91f574f3d4
# be397c29-0766-4bf0-a315-fa230d7e41d9  b2af6377-ea73-4520-8f55-8b91f574f3d4
# be397c29-0766-4bf0-a315-fa230d7e41d9  b2af6377-ea73-4520-8f55-8b91f574f3d4
# be397c29-0766-4bf0-a315-fa230d7e41d9  b2af6377-ea73-4520-8f55-8b91f574f3d4
# be397c29-0766-4bf0-a315-fa230d7e41d9  b2af6377-ea73-4520-8f55-8b91f574f3d4
#
# ...

# %%
print(f"There is {len(failed_transc)} failed transanction in Korea")
print(f"There is {len(successful_transc)} sucessful transanction in Korea")
print(f"There is {len(cancelled_transc)} cancelled transanction in Korea")
# Out:
# There is 1982 failed transanction in Korea
# There is 2444 sucessful transanction in Korea
# There is 2571 cancelled transanction in Korea

# %%
# out of this 1,982 customers that experiences failed transaction lets see the numbers of unique customers that there...
failed_transc.index.nunique()
# Out:
# 11

# %%
failed_transc.index.unique()
# Out:
# Index(['34d3c5e1-7e40-40c9-84c3-7d50edfb7eaf',
#        '2933e91f-39d6-44af-b1e8-933ad172a3c6',
#        'b20fe203-25fc-4ad8-96e9-5c8031093064',
#        'c9b3c52a-9b77-4d33-b9eb-5a3a34dc5810',
#        'ea2aa16a-a791-47f0-95c5-066d17b5f09d',
#        '39568cc0-3642-4234-9b88-c339d6953adf',
#        'cd03dc6b-c884-433b-9e01-735e19ade944',
#        '66e4bef6-a448-4e9e-b807-14a06728753f',
#        '8498e8be-5899-4ad4-821f-d0df3da83157',
#        'b4139e14-0478-41f0-bcbb-6792f0c6d957',
#        'be397c29-0766-4bf0-a315-fa230d7e41d9'],
#       dtype='object', name='customer_id')

# %%
cust_34d3c5e1 = (failed_transc.index== "34d3c5e1-7e40-40c9-84c3-7d50edfb7eaf")

# %%
failed_transc[cust_34d3c5e1].head(5)
# Out:
#                                                                  device_id  \
# customer_id
# 34d3c5e1-7e40-40c9-84c3-7d50edfb7eaf  05ec37c1-5bb4-4033-908b-366e25c02f66
# 34d3c5e1-7e40-40c9-84c3-7d50edfb7eaf  05ec37c1-5bb4-4033-908b-366e25c02f66
# 34d3c5e1-7e40-40c9-84c3-7d50edfb7eaf  05ec37c1-5bb4-4033-908b-366e25c02f66
# 34d3c5e1-7e40-40c9-84c3-7d50edfb7eaf  05ec37c1-5bb4-4033-908b-366e25c02f66
# 34d3c5e1-7e40-40c9-84c3-7d50edfb7eaf  05ec37c1-5bb4-4033-908b-366e25c02f66
#
#                                       item_id  line_item_id  \
# customer_id
# 34d3c5e1-7e40-40c9-84c3-7d50edfb7eaf        4          4123
# 34d3c5e1-7e40-40c9-84c3-7d50edfb7eaf        7          4124
# 34d3c5e1-7e40-40c9-84c3-7d50edfb7eaf       12          4125
# 34d3c5e1-7e40-40c9-84c3-7d50edfb7eaf       14          4126
# 34d3c5e1-7e40-40c9-84c3-7d50edfb7eaf        5          4127
#
#                                                                   order_id  \
# customer_id
# ...

# %%
len(failed_transc[cust_34d3c5e1])
# This particular customer attempted 198 transactions that failed
# Out:
# 198

# %%
successful_transc[successful_transc.index == "34d3c5e1-7e40-40c9-84c3-7d50edfb7eaf"]
# Out:
# Empty DataFrame
# Columns: [device_id, item_id, line_item_id, order_id, event_id, event_timestamp, quantity, currency, checked_out_at, status, location]
# Index: []

# %%
df_korea.currency.unique()
# Out:
# array(['USD', 'GBP', 'NGN'], dtype=object)

# %%
df_korea.currency.value_counts()
# Out:
# currency
# USD    3065
# NGN    1983
# GBP    1949
# Name: count, dtype: int64

# %%
df_korea.currency.value_counts().plot(kind = "bar")
plt.ylabel("Frequency")
plt.title("Frequency of Currency in Korea")
# Out:
# Text(0.5, 1.0, 'Frequency of Currency in Korea')

# %%
df_korea["status"].unique()
# Out:
# array(['cancelled', 'success', 'failed'], dtype=object)

# %%
df_korea.status.value_counts()
# Out:
# status
# cancelled    2571
# success      2444
# failed       1982
# Name: count, dtype: int64

# %%
df_korea.status.value_counts().plot(kind = "bar")
plt.ylabel("Frequency")
plt.title("Frequency of Transanction in Korea")
# Out:
# Text(0.5, 1.0, 'Frequency of Transanction in Korea')
